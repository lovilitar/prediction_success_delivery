# %%
import sys
import os

# %%
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import pandas as pd
from src.setting.settings import setup_logger, dbm
import numpy as np
import seaborn as sns
import importlib
from datetime import datetime, timedelta
from typing import Tuple

# %%
from src.utils import decorators, logger
from src.data_loader import raw_data_loader
from src.preprocessor import preprocessing
from src.splitter import splitter
from src.pipeline import data_preparation_pipeline, model_pipeline

importlib.reload(decorators)
importlib.reload(logger)
importlib.reload(raw_data_loader)
importlib.reload(splitter)
importlib.reload(preprocessing)
importlib.reload(data_preparation_pipeline)
importlib.reload(model_pipeline)

from src.utils.decorators import start_finish_function
from src.utils.logger import CustomFormatter
from src.data_loader.raw_data_loader import get_df
from src.preprocessor.preprocessing import ManagerPreprocessing
from src.splitter.splitter import FixedDateTrainTestSplitter, TimeBasedSubsetSelector, SplitManager
from src.pipeline.data_preparation_pipeline import TrainTestPreparer
from src.pipeline.model_pipeline import XGBoostPipelineBuilder

# %%
engine = dbm.get_engine()

# %%
df = get_df(engine)
# Out:
# [2025-05-01 14:59:31] [INFO] [decorators.wrapper] Старт выполнения метода 'Engine.get_df'
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Завершение выполнения метода 'Engine.get_df'. Время выполнения: 12.87 секунд

# %%
feature_name = ['delivery_point', 'rasstoyanie', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'date_create', 'tonnazh', 'obem_znt', 'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki']

x_train, y_train, x_test, y_test, x_subset, y_subset = TrainTestPreparer(feature_columns=feature_name).prepare(df)
# Out:
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Старт выполнения метода 'TrainTestPreparer.prepare'
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing.preprocess'
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing._dropna'
# [2025-05-01 14:59:45] [INFO] [preprocessing.ManagerPreprocessing._dropna] Удалено пустых столбцов: 295 шт, осталось 618328
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing._dropna'. Время выполнения: 0.45 секунд
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Старт выполнения метода 'DatetimePreprocessor.transform'
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Завершение выполнения метода 'DatetimePreprocessor.transform'. Время выполнения: 0.64 секунд
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Старт выполнения метода 'TargetCreator.transform'
# [2025-05-01 14:59:58] [INFO] [decorators.wrapper] Завершение выполнения метода 'TargetCreator.transform'. Время выполнения: 12.66 секунд
# [2025-05-01 14:59:58] [INFO] [decorators.wrapper] Старт выполнения метода 'RareCityDropper.transform'
# [2025-05-01 15:00:00] [INFO] [decorators.wrapper] Завершение выполнения метода 'RareCityDropper.transform'. Время выполнения: 1.41 секунд
# [2025-05-01 15:00:00] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoryFeatureEngineer.transform'
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoryFeatureEngineer.transform'. Время выполнения: 1.24 секунд
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Старт выполнения метода 'GeospatialFeatureEngineer.transform'
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Завершение выполнения метода 'GeospatialFeatureEngineer.transform'. Время выполнения: 0.26 секунд
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing.set_correct_datetype'
# [2025-05-01 15:00:02] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing.set_correct_datetype'. Время выполнения: 1.21 секунд
# [2025-05-01 15:00:02] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing.preprocess'. Время выполнения: 17.95 секунд
# [2025-05-01 15:00:03] [INFO] [decorators.wrapper] Старт выполнения метода 'SplitManager.run'
# [2025-05-01 15:00:03] [INFO] [decorators.wrapper] Старт выполнения метода 'FixedDateTrainTestSplitter.split'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'FixedDateTrainTestSplitter.split'. Время выполнения: 1.01 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.17 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.01 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'SplitManager.run'. Время выполнения: 1.23 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'SplitManager.run'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'FixedDateTrainTestSplitter.split'
# [2025-05-01 15:00:05] [INFO] [decorators.wrapper] Завершение выполнения метода 'FixedDateTrainTestSplitter.split'. Время выполнения: 0.85 секунд
# [2025-05-01 15:00:05] [INFO] [decorators.wrapper] Старт выполнения метода 'TimeBasedSubsetSelector.select'
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'TimeBasedSubsetSelector.select'. Время выполнения: 0.72 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.08 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.01 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'SplitManager.run'. Время выполнения: 1.70 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'TrainTestPreparer.prepare'. Время выполнения: 22.49 секунд

# %% [markdown]
# ## Предобработка

# %%
df['planned_delivery_days'], df['y'] = Preprocessing.create_target(df)

# %%
columns_params = ['delivery_point', 'rasstoyanie', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'date_create', 'tonnazh', 'obem_znt', 'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki', 'voditel', 'planned_delivery_days', 'y']
df_preparation = df[columns_params].copy()
df_preparation.shape
# Out:
# (618623, 16)

# %%
df_preparation = df_preparation.dropna(subset=[col for col in df_preparation.columns if col != 'voditel'])
df_preparation.shape
# Out:
# (618328, 16)

# %% [markdown]
# ### Категориальные фичи

# %%
obj_col = df_preparation.select_dtypes(include=np.object_).columns
obj_col = obj_col.drop('voditel')

for col in obj_col:
    counts = df_preparation[col].value_counts()
    valid_values = counts[counts > 5].index
    df_preparation = df_preparation[df_preparation[col].isin(valid_values)]

print(f"Финальный размер: {df_preparation.shape}")
# Out:
# Финальный размер: (618224, 16)

# %% [markdown]
# ### Новые фичи

# %%
def assign_group(distance):
    if pd.isna(distance):
        return np.nan
    if distance == 0:
        return 0
    elif distance < 1000:
        return (distance // 100) * 100
    else:
        return (distance // 1000) * 1000

def tonnazh_group(tonnazh):
    if pd.isna(tonnazh):
        return np.nan
    if tonnazh == 0:
        return 0
    elif tonnazh < 1:
        return round((tonnazh // 0.1) * 0.1, 1)
    elif tonnazh < 5:
        return (tonnazh // 1) * 1
    elif tonnazh < 10:
        return 5
    else:
        return 10

def cost_group(cost):
    if pd.isna(cost):
        return np.nan
    if cost == 0:
        return 0
    elif cost < 10000:
        return (cost // 1000) * 1000
    elif cost < 50000:
        return (cost // 10000) * 10000
    elif 50000 < cost < 150000:
        return (cost // 50000) * 50000
    elif 150000 < cost < 500001:
        return 150000
    else:
        return 500000

# %%
df_preparation['distance_group'] = df_preparation['rasstoyanie'].map(assign_group)

df_preparation['distance_group'] = df_preparation['distance_group'].astype('int')

df_preparation['tonnazh_group'] = df_preparation['tonnazh'].map(tonnazh_group)

# df_preparation['tonnazh_group'] = df_preparation['tonnazh_group'].astype('int')

df_preparation['cost_group'] = df_preparation['lt_stoimost_perevozki'].map(cost_group)

df_preparation['cost_group'] = df_preparation['cost_group'].astype('int')

# %% [markdown]
# ### Геопространственные признаки

# %%
R = 6371.0

# Преобразуем координаты из градусов в радианы
lat1 = np.radians(df_preparation['lat_zagruzki'].values)
lon1 = np.radians(df_preparation['lng_zagruzki'].values)
lat2 = np.radians(df_preparation['lat_vygruzki'].values)
lon2 = np.radians(df_preparation['lng_vygruzki'].values)

# Разница координат
dlat = lat2 - lat1
dlon = lon2 - lon1

# Формула гаверсинуса
a = np.sin(dlat / 2.0) ** 2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2.0) ** 2
c = 2 * np.arcsin(np.sqrt(a))

# Вычисляем расстояние
df_preparation['geo_rasstoyanie_km'] = R * c

# %% [markdown]
# ### Временные фичи

# %%
df_preparation['year']=df_preparation.date_create.dt.year
df_preparation['month']=df_preparation.date_create.dt.month

df_preparation.sort_values('date_create', inplace=True)

# %% [markdown]
# ## Обучение модели

# %%
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.model_selection import GridSearchCV, TimeSeriesSplit

from sklearn.svm import LinearSVC

from sklearn.metrics import (make_scorer, accuracy_score, f1_score, 
                            average_precision_score, precision_score, recall_score, 
                            precision_recall_fscore_support, fbeta_score)
from sklearn.inspection import permutation_importance

import matplotlib.pyplot as plt

# %% [markdown]
# ### Функции

# %%
def df_split_test_and_train(
        df, date_column='date_create',
        test_count_days=90
    ) -> Tuple[pd.DataFrame, pd.Series, pd.DataFrame, pd.Series]:
    df_split = df.copy()
    df_split = df_split.sort_values(date_column)

    split_date = df_split[date_column].max() - timedelta(test_count_days)

    train_df = df_split[df_split[date_column] < split_date]
    test_df = df_split[df_split[date_column] >= split_date]

    X_train = train_df.drop(['y'], axis=1)
    y_train = train_df.y
    X_test = test_df.drop(['y'], axis=1)
    y_test = test_df.y
    return X_train, y_train, X_test, y_test

def select_time_based_subset(df, percent=0.2, n_segments=5):
    total_len = len(df)
    segment_size = int((total_len * percent) / n_segments)
    
    indices = []
    step = (total_len - segment_size) // (n_segments - 1)

    for i in range(n_segments):
        start_idx = i * step
        end_idx = start_idx + segment_size
        indices.extend(range(start_idx, end_idx))

    df_subset = df.iloc[indices]
    return df_subset
    

def optimize_threshold(y_true, y_proba, metric=f1_score):
    thresholds = np.linspace(0.1, 0.9, 81)
    scores = [metric(y_true, (y_proba >= t).astype(int)) for t in thresholds]
    best_t = thresholds[np.argmax(scores)]
    return round(best_t, 3), round(max(scores), 3)

def optimal_threshold_cv(model, X, y, score_method=f1_score, cv_splits=3):
    thresholds = np.linspace(0.1, 0.9, 81)  # Шаг 0.01
    tss = TimeSeriesSplit(n_splits=cv_splits)

    best_thresholds = []
    best_scores = []

    for train_idx, val_idx in tss.split(X):
        X_train, X_val = X.iloc[train_idx], X.iloc[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]

        model.fit(X_train, y_train)
        val_probs = model.predict_proba(X_val)[:, 1]

        scores = []
        for thresh in thresholds:
            val_pred = (val_probs >= thresh).astype(int)
            score = score_method(y_val, val_pred)
            scores.append(score)

        # Берем порог с максимальным F1 на текущем фолде
        best_idx = np.argmax(scores)
        best_thresholds.append(thresholds[best_idx])
        best_scores.append(scores[best_idx])

    optimal_threshold = np.mean(best_thresholds)
    optimal_scores = np.mean(best_scores)

    return optimal_threshold, optimal_scores

# %%
def get_df_p_r_f1_auc_fr(pipe, x_train, y_train, x_test, y_test, best_threshold=None):
    pipe.fit(x_train, y_train)
    
    y_train_proba = pipe.predict_proba(x_train)[:, 1]
    y_test_proba = pipe.predict_proba(x_test)[:, 1]
    
    # Подбор лучшего порога отсечения (по train)
    if not best_threshold:
        best_threshold, best_f1 = optimize_threshold(y_train, y_train_proba)
        print(f'Подобраный порог отсечения: {best_threshold}')
    else:
        print(f'Лучший порог отсечения: {best_threshold}')
        pass
    
    # === 2. Применение порога и замер на TRAIN ===
    y_best_train_pred = (y_train_proba >= best_threshold).astype(int)
    precision_train, recall_train, f1_train, _ = precision_recall_fscore_support(
        y_train, y_best_train_pred, average='binary'
    )
    auc_fr_train = average_precision_score(y_train, y_train_proba)
    
    # === 3. Применение порога и замер на TEST ===
    y_best_test_pred = (y_test_proba >= best_threshold).astype(int)
    precision_test, recall_test, f1_test, _ = precision_recall_fscore_support(
        y_test, y_best_test_pred, average='binary'
    )
    auc_fr_test = average_precision_score(y_test, y_test_proba)
    
    # === 4. Вывод результата ===
    results = {
        'threshold': best_threshold,
        'train': {
            'precision': round(precision_train, 4),
            'recall': round(recall_train, 4),
            'f1': round(f1_train, 4),
            'ap': round(auc_fr_train, 4)
        },
        'test': {
            'precision': round(precision_test, 4),
            'recall': round(recall_test, 4),
            'f1': round(f1_test, 4),
            'ap': round(auc_fr_test, 4)
        }
    }
    
    return pd.DataFrame(results).T

# %%
df_for_split = df_preparation.copy()
df_for_split.head(1)
# Out:
#         delivery_point  rasstoyanie  region_zagruzki  lat_zagruzki  \
# 324453               1        800.0  Приморский край     42.845616
#
#         lng_zagruzki     region_vygruzki  lat_vygruzki  lng_vygruzki  \
# 324453    132.571133  Смоленская область      55.19187     34.346061
#
#        date_create  tonnazh  ...  lt_stoimost_perevozki  \
# 324453  2016-11-01     0.25  ...                    0.0
#
#                                      voditel  planned_delivery_days  y  \
# 324453  f920e2f0-cfcd-11e5-80e4-005056010e02                      9  1
#
#         distance_group  tonnazh_group  cost_group  geo_rasstoyanie_km  year  \
# 324453             800            0.2           0         6682.931393  2016
#
#         month
# 324453     11
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Препроцесинг

# %%
x_test.columns
# Out:
# Index(['znt_ssylka', 'delivery_point', 'rasstoyanie', 'date_create',
#        'date_fakticheskaya_vygruzki', 'tonnazh', 'obem_znt', 'adres_zagruzki',
#        'adres_vygruzki', 'country_zagruzki', 'region_zagruzki',
#        'city_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'country_vygruzki',
#        'region_vygruzki', 'city_vygruzki', 'lat_vygruzki', 'lng_vygruzki',
#        'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki', 'voditel', 'year',
#        'month', 'planned_delivery_days', 'distance_group', 'tonnazh_group',
#        'cost_group', 'geo_rasstoyanie_km'],
#       dtype='object')

# %%
df_for_split.drop(['year', 'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki', 'obem_znt', 'voditel'], axis=1, inplace=True)
df_for_split.shape
# Out:
# (618224, 17)

# %%
x_train, y_train, x_test, y_test = df_split_test_and_train(df_for_split)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
obj_columns = ['distance_group', 'cost_group', 'region_zagruzki', 'region_vygruzki']
exclude_columns = ['year', 'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki', 'obem_znt', 'voditel', 'date_create']

col_for_one_idx = [list(x_train.columns).index(col_name) for col_name in obj_columns]

not_obj_columns = x_train.select_dtypes(exclude=object).columns
numeric_col = not_obj_columns.difference(exclude_columns).difference(obj_columns)
numeric_cols_idx = [list(x_train.columns).index(col_name) for col_name in numeric_col]

ohe = OneHotEncoder(handle_unknown='ignore', sparse_output=False)

t = [('OHE', ohe, col_for_one_idx),
    ('StandardScaler', StandardScaler(), numeric_cols_idx)]

col_transformer = ColumnTransformer(transformers=t, verbose_feature_names_out=True)

# %% [markdown]
# ## Бустинг

# %%
import xgboost as xgb

# %%
xgb.__version__
# Out:
# '3.0.0'

# %%
pipe_boost = Pipeline(steps=[
    ('column_transformer', col_transformer),
    ('model_boost', xgb.XGBClassifier(eval_metric='logloss'))
])

pipe_boost.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('column_transformer',
#                  ColumnTransformer(transformers=[('OHE',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   [11, 13, 2, 5]),
#                                                  ('StandardScaler',
#                                                   StandardScaler(),
#                                                   [0, 14, 6, 3, 7, 4, 15, 10, 1,
#                                                    9, 12])])),
#                 ('model_boost',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
pipe_boost.predict_proba()
# Out:
# array([[0.73903394, 0.2609661 ],
#        [0.4185412 , 0.5814588 ],
#        [0.9321746 , 0.06782539],
#        ...,
#        [0.89190894, 0.10809105],
#        [0.9028682 , 0.09713177],
#        [0.9364233 , 0.0635767 ]], dtype=float32)

# %%
param_grid = {
    'model_boost__n_estimators': [100, 200],
    'model_boost__max_depth': [3, 5, 7],
    'model_boost__learning_rate': [0.01, 0.1, 0.3],
    # 'model_boost__subsample': [0.8, 1.0],
    # 'model_boost__colsample_bytree': [0.8, 1.0]
}

param_scoring = {
    'accuracy': make_scorer(accuracy_score),
    'f1': make_scorer(f1_score),
    'ap': make_scorer(average_precision_score)
}

# Как правильно разделить данные чтобы оставить только 20% данных
df_subset = select_time_based_subset(df_for_split, percent=0.2, n_segments=5)

X_subset = df_subset.drop(columns='y')
y_subset = df_subset['y']

tss = TimeSeriesSplit(n_splits=3)

search = GridSearchCV(estimator=pipe_boost, 
                      param_grid=param_grid,
                      scoring=param_scoring, 
                      refit='ap',
                      cv=tss,
                      n_jobs=-1, 
                      verbose=10, 
                      return_train_score=True
                      )
search.fit(X_subset, y_subset)

print(f"Лучшие параметры модели: {search.best_params_}")
best_model = search.best_estimator_

# # Калибровка вероятностей
# calibrated_model = CalibratedClassifierCV(base_estimator=best_model, method='sigmoid', cv=tss)
# calibrated_model.fit(X_subset, y_subset)

# Подбор лучшего порога отсечения
optimal_threshold, optimal_f1 = optimal_threshold_cv(
    best_model, 
    X_subset, 
    y_subset, 
    cv_splits=3
)

x_train, y_train, x_test, y_test = df_split_test_and_train(df_for_split)

boost_res_df = get_df_p_r_f1_auc_fr(
    best_model,
    x_train,
    y_train,
    x_test,
    y_test,
    best_threshold=optimal_threshold
)

boost_res_df
# Out:
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# Лучшие параметры модели: {'model_boost__learning_rate': 0.3, 'model_boost__max_depth': 3, 'model_boost__n_estimators': 200}
# Лучший порог отсечения: 0.29000000000000004
#            precision  recall      f1      ap
# threshold     0.2900  0.2900  0.2900  0.2900
# train         0.5136  0.8054  0.6272  0.6779
# test          0.2996  0.8875  0.4480  0.5474

# %% [markdown]
# ## Пересборка для продакшена

# %%
from src.utils import decorators, logger
from src.data_loader import raw_data_loader
from src.preprocessor import preprocessing
from src.splitter import splitter
from src.pipeline import data_preparation_pipeline, model_pipeline

importlib.reload(decorators)
importlib.reload(logger)
importlib.reload(raw_data_loader)
importlib.reload(splitter)
importlib.reload(preprocessing)
importlib.reload(data_preparation_pipeline)
importlib.reload(model_pipeline)

from src.utils.decorators import start_finish_function
from src.utils.logger import CustomFormatter
from src.data_loader.raw_data_loader import get_df
from src.preprocessor.preprocessing import ManagerPreprocessing
from src.splitter.splitter import FixedDateTrainTestSplitter, TimeBasedSubsetSelector, SplitManager
from src.pipeline.data_preparation_pipeline import TrainTestPreparer
from src.pipeline.model_pipeline import transform_pipe

# %%
from src.features.column_transformers import FeatureSelection, CategoricalTypeCaster
from src.setting.settings import setup_logger
from sklearn.pipeline import Pipeline
from xgboost import XGBClassifier

from sklearn.model_selection import GridSearchCV, TimeSeriesSplit
from sklearn.metrics import make_scorer, accuracy_score, f1_score, average_precision_score, precision_recall_fscore_support

# %%
engine = dbm.get_engine()

# %%
df = get_df(engine)
# Out:
# [2025-05-01 14:59:31] [INFO] [decorators.wrapper] Старт выполнения метода 'Engine.get_df'
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Завершение выполнения метода 'Engine.get_df'. Время выполнения: 12.87 секунд

# %%
feature_name = ['delivery_point', 'rasstoyanie', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'date_create', 'tonnazh', 'obem_znt', 'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki']

x_train, y_train, x_test, y_test, x_subset, y_subset = TrainTestPreparer(feature_columns=feature_name).prepare(df)
# Out:
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Старт выполнения метода 'TrainTestPreparer.prepare'
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing.preprocess'
# [2025-05-01 14:59:44] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing._dropna'
# [2025-05-01 14:59:45] [INFO] [preprocessing.ManagerPreprocessing._dropna] Удалено пустых столбцов: 295 шт, осталось 618328
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing._dropna'. Время выполнения: 0.45 секунд
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Старт выполнения метода 'DatetimePreprocessor.transform'
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Завершение выполнения метода 'DatetimePreprocessor.transform'. Время выполнения: 0.64 секунд
# [2025-05-01 14:59:45] [INFO] [decorators.wrapper] Старт выполнения метода 'TargetCreator.transform'
# [2025-05-01 14:59:58] [INFO] [decorators.wrapper] Завершение выполнения метода 'TargetCreator.transform'. Время выполнения: 12.66 секунд
# [2025-05-01 14:59:58] [INFO] [decorators.wrapper] Старт выполнения метода 'RareCityDropper.transform'
# [2025-05-01 15:00:00] [INFO] [decorators.wrapper] Завершение выполнения метода 'RareCityDropper.transform'. Время выполнения: 1.41 секунд
# [2025-05-01 15:00:00] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoryFeatureEngineer.transform'
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoryFeatureEngineer.transform'. Время выполнения: 1.24 секунд
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Старт выполнения метода 'GeospatialFeatureEngineer.transform'
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Завершение выполнения метода 'GeospatialFeatureEngineer.transform'. Время выполнения: 0.26 секунд
# [2025-05-01 15:00:01] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing.set_correct_datetype'
# [2025-05-01 15:00:02] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing.set_correct_datetype'. Время выполнения: 1.21 секунд
# [2025-05-01 15:00:02] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing.preprocess'. Время выполнения: 17.95 секунд
# [2025-05-01 15:00:03] [INFO] [decorators.wrapper] Старт выполнения метода 'SplitManager.run'
# [2025-05-01 15:00:03] [INFO] [decorators.wrapper] Старт выполнения метода 'FixedDateTrainTestSplitter.split'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'FixedDateTrainTestSplitter.split'. Время выполнения: 1.01 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.17 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.01 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Завершение выполнения метода 'SplitManager.run'. Время выполнения: 1.23 секунд
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'SplitManager.run'
# [2025-05-01 15:00:04] [INFO] [decorators.wrapper] Старт выполнения метода 'FixedDateTrainTestSplitter.split'
# [2025-05-01 15:00:05] [INFO] [decorators.wrapper] Завершение выполнения метода 'FixedDateTrainTestSplitter.split'. Время выполнения: 0.85 секунд
# [2025-05-01 15:00:05] [INFO] [decorators.wrapper] Старт выполнения метода 'TimeBasedSubsetSelector.select'
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'TimeBasedSubsetSelector.select'. Время выполнения: 0.72 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.08 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.01 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'SplitManager.run'. Время выполнения: 1.70 секунд
# [2025-05-01 15:00:06] [INFO] [decorators.wrapper] Завершение выполнения метода 'TrainTestPreparer.prepare'. Время выполнения: 22.49 секунд

# %%
x_train, y_train, x_test, y_test, x_subset, y_subset
# Out:
# (                                  znt_ssylka  delivery_point  rasstoyanie  \
#  232442  604815f3-a024-11e6-80e9-00505601119a               1        300.0
#  564223  e996deeb-a004-11e6-80e9-00505601119a               1        800.0
#  324453  8651afc8-a039-11e6-80eb-00505601119b               1        800.0
#  329956  8898f219-a038-11e6-80eb-00505601119b               1       7300.0
#  150338  3e736c0c-a038-11e6-80eb-00505601119b               1        650.0
#  ...                                      ...             ...          ...
#  437895  b5513647-0830-48df-9476-d479a5983d89               1       9000.0
#  580457  f03cb792-76a0-44c1-bf45-6c210b30e3d3               1        500.0
#  358647  9488003d-4a14-451c-930b-3cf202905390               2       1760.0
#  499304  cecf7dd5-b084-11ef-9c64-3a68dd4bd927               1       5700.0
#  170521  46bb2efb-b0b0-11ef-9c64-3a68dd4bd927               1       1500.0
#
#         date_create date_fakticheskaya_vygruzki  tonnazh  obem_znt  \
#  232442  2016-11-01                  2016-11-09    0.200     4.935
#  564223  2016-11-01                  2016-11-11    0.300     0.300
#  324453  2016-11-01                  2016-11-16    0.250     0.400
#  329956  2016-11-01                  2017-01-14    0.030     0.060
#  150338  2016-11-01                  2016-11-15    0.300     0.600
#  ...            ...                         ...      ...       ...
#  437895  2024-12-02                  2024-12-13    0.003     0.007
#  580457  2024-12-02                  2024-12-17    0.400     0.960
#  358647  2024-12-02                  2024-12-19    0.050     0.300
#  499304  2024-12-02                  2024-12-06    0.500     0.500
#  170521  2024-12-02                  2024-12-04    0.036     0.045
#
#                                             adres_zagruzki  \
#  232442  150044, Ярославская обл, г. Ярославль, ул. Ост...
#  564223  150044, Ярославская обл, г. Ярославль, ул. Ост...
#  324453  г.Иваново ул. Станкостроителей 3Б, ООО "Корона...
#  329956  Владимирская обл., Вязниковский р-он, пгт Нико...
#  150338  Владимирская обл., Вязниковский р-он, пгт Нико...
#  ...                                                   ...
#  437895  143912, Московская область, г Балашиха, ш Энту...
#  580457  620085, Свердловская область, г Екатеринбург, ...
#  358647  187401, Ленинградская область, р-н Волховский,...
#  499304  150030, Ярославская обл, г Ярославль, ул Ползу...
#  170521  155805, Ивановская обл, г Кинешма, ул Вичугска...
#
#                                             adres_vygruzki country_zagruzki  \
#  232442  150030, Ярославская обл, Ярославль г, Ползунов...           Россия
#  564223  394061, Воронежская обл, Воронеж г, Свердлова,...           Россия
#  324453  215113, Смоленская обл, Вяземский р-н, Вязьма ...           Россия
#  329956  676280, Амурская обл, Тында г, Привокзальная у...           Россия
#  150338  394010, Воронежская обл, Воронеж г, Богдана Хм...           Россия
#  ...                                                   ...              ...
#  437895  692510, Приморский край, г Уссурийск, пр-кт Бл...           Россия
#  580457  344001, Ростовская область, г Ростов-на-Дону, ...           Россия
#  358647  396653, Воронежская область, р-н Россошанский,...           Россия
#  499304  670002, Бурятия Респ, г Улан-Удэ, ул Лимонова,...           Россия
#  170521  614031, Пермский край, г Пермь, ул Транспортна...           Россия
#
#          ... kolvo_gruzovykh_mest lt_stoimost_perevozki  \
#  232442  ...                    0                   0.0
#  564223  ...                    0                   0.0
#  324453  ...                    0                   0.0
#  329956  ...                    0                   0.0
#  150338  ...                    0                   0.0
#  ...     ...                  ...                   ...
#  437895  ...                    1               44250.0
#  580457  ...                    2               29396.0
#  358647  ...                    1               32774.0
#  499304  ...                    5              297495.0
#  170521  ...                    1               20000.0
#
#                                       voditel  year month  \
#  232442  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  564223  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  324453  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  329956  50798750-be08-11e6-80e9-00505601119a  2016    11
#  150338  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  ...                                      ...   ...   ...
#  437895  a7c7725d-7cd9-11eb-b3d3-3868dd0e0ca3  2024    12
#  580457  51f40f2a-b731-11ef-9c66-3a68dd4bd927  2024    12
#  358647                                  None  2024    12
#  499304  41143706-7cd7-11ef-9c64-3a68dd4bd927  2024    12
#  170521  63aebf55-5f36-11e8-80ee-00505601119a  2024    12
#
#         planned_delivery_days distance_group  tonnazh_group  cost_group  \
#  232442                     8            300            0.2           0
#  564223                     9            800            0.2           0
#  324453                     9            800            0.2           0
#  329956                    30           7000            0.0           0
#  150338                     9            600            0.2           0
#  ...                      ...            ...            ...         ...
#  437895                    35           9000            0.0       40000
#  580457                     9            500            0.4       20000
#  358647                    18           1000            0.0       30000
#  499304                    24           5000            0.4      150000
#  170521                    11           1000            0.0       20000
#
#          geo_rasstoyanie_km
#  232442            7.413426
#  564223          665.840816
#  324453         6682.931393
#  329956         4871.810163
#  150338          523.634799
#  ...                    ...
#  437895         6348.356505
#  580457         1772.173811
#  358647         1176.072619
#  499304         4211.630186
#  170521          833.798402
#
#  [603868 rows x 29 columns],
#  232442    0
#  564223    1
#  324453    1
#  329956    1
#  150338    1
#           ..
#  437895    0
#  580457    1
#  358647    0
#  499304    0
#  170521    0
#  Name: y, Length: 603868, dtype: int64,
#                                    znt_ssylka  delivery_point  rasstoyanie  \
#  369285  98e9306b-64c7-49c2-a8d1-78fc1c32c1ff               1       4503.0
#  278161  731de2f1-08f5-48db-8c4f-70b6fff3694b               3       4050.0
#  31890   0d5c9d3a-7aeb-4e2a-804d-f2a4d3858f70               2       1500.0
#  488172  ca2fe24d-b183-11ef-9c65-3a68dd4bd927               1       2000.0
#  30328   0cbc2c95-b14c-11ef-9c64-3a68dd4bd927               1        200.0
#  ...                                      ...             ...          ...
#  306434  7ee370c0-f5d7-11ef-9c68-3a68dd4bd927               1         50.0
#  42517   11c9302a-f5d4-11ef-9c68-3a68dd4bd927               1         70.0
#  57911   1830a977-e513-43ce-9861-3c2b9f1c94b7               1        173.0
#  216895  59df4155-f7c3-11ef-9c68-3a68dd4bd927               1        100.0
#  402132  a69a752e-f812-11ef-9c68-3a68dd4bd927               1       2500.0
#
#         date_create date_fakticheskaya_vygruzki  tonnazh  obem_znt  \
#  369285  2024-12-03                  2024-12-23    0.010     0.001
#  278161  2024-12-03                  2025-01-20    0.012     0.068
#  31890   2024-12-03                  2024-12-17    0.009     0.125
#  488172  2024-12-03                  2024-12-07    5.000     3.500
#  30328   2024-12-03                  2024-12-06   20.000     1.000
#  ...            ...                         ...      ...       ...
#  306434  2025-02-28                  2025-03-03    1.400     1.728
#  42517   2025-02-28                  2025-03-03    1.400     1.728
#  57911   2025-03-03                  2025-03-03    2.000     0.875
#  216895  2025-03-03                  2025-03-04   28.000     5.000
#  402132  2025-03-03                  2025-03-04    4.000     5.000
#
#                                             adres_zagruzki  \
#  369285  673460, Забайкальский край, р-н Чернышевский, ...
#  278161  632863, Новосибирская область, р-н Карасукский...
#  31890   182670, Псковская область, м.р-н Дновский, г.п...
#  488172  115088, Москва г, ул Южнопортовая, д. 21, стр. 11
#  30328   352708, Краснодарский край, р-н Тимашевский, г...
#  ...                                                   ...
#  306434  172008, Тверская обл, г Торжок, ул Героя Росси...
#  42517   172008, Тверская обл, г Торжок, ул Героя Росси...
#  57911   214010, Смоленская область, г Смоленск, ул Кал...
#  216895  692390, Приморский край, р-н Черниговский, пгт...
#  402132     644058, Омская обл, г Омск, ул Деповская, д. 1
#
#                                             adres_vygruzki country_zagruzki  \
#  369285  625000, Тюменская область, г Тюмень, ул Привок...           Россия
#  278161  664013, Иркутская область, г Иркутск, ул Вокза...           Россия
#  31890   160023, Вологодская область, г Вологда, ул Мож...           Россия
#  488172  620090, Свердловская обл, г Екатеринбург, ул Э...           Россия
#  30328   344001, Ростовская обл, г.о. город Ростов-на-Д...           Россия
#  ...                                                   ...              ...
#  306434  170003, Тверская обл, г Тверь, ш Петербургское...           Россия
#  42517   170039, Тверская обл, г Тверь, ул Паши Савелье...           Россия
#  57911   215111, Смоленская область, м.р-н Вяземский, г...           Россия
#  216895  692510, Приморский край, г Уссурийск, пр-кт Бл...           Россия
#  402132  652400, Кемеровская область - Кузбасс, г Тайга...           Россия
#
#          ... kolvo_gruzovykh_mest lt_stoimost_perevozki  \
#  369285  ...                    1               1300.26
#  278161  ...                    3              51570.00
#  31890   ...                    1              17609.00
#  488172  ...                    1             107500.00
#  30328   ...                    1              80400.00
#  ...     ...                  ...                   ...
#  306434  ...                    1               3000.00
#  42517   ...                    1               3000.00
#  57911   ...                    3              20574.00
#  216895  ...                    4             162000.00
#  402132  ...                    1              35700.19
#
#                                       voditel  year month  \
#  369285  289ff55b-ca4a-11ee-9662-3a68dd4bd4bf  2024    12
#  278161                                  None  2024    12
#  31890                                   None  2024    12
#  488172  9512c820-89ed-11ee-b3ee-3a68dd0e0ca7  2024    12
#  30328   5d4d6b30-1a5d-11ea-b3cf-3a68dd0e0ca7  2024    12
#  ...                                      ...   ...   ...
#  306434  4e5884c3-13a7-11eb-b3d2-3a68dd0e0ca7  2025     2
#  42517   1b79aefe-3fb4-11eb-b3d2-3a68dd0e0ca7  2025     2
#  57911   b7adc683-f422-11e6-80e9-00505601119a  2025     3
#  216895  d008f173-4b30-11ee-b3ee-3a68dd0e0ca7  2025     3
#  402132  70329d56-03d5-11ef-9662-3a68dd4bd4bf  2025     3
#
#         planned_delivery_days distance_group  tonnazh_group  cost_group  \
#  369285                    22           4000            0.0        1000
#  278161                    34           4000            0.0       50000
#  31890                     20           1000            0.0       10000
#  488172                    14           2000            5.0      100000
#  30328                      8            200           10.0       50000
#  ...                      ...            ...            ...         ...
#  306434                    10              0            1.0        3000
#  42517                     10              0            1.0        3000
#  57911                      8            100            2.0       20000
#  216895                     8            100           10.0      150000
#  402132                    15           2000            4.0       30000
#
#          geo_rasstoyanie_km
#  369285         3257.802764
#  278161         1748.071042
#  31890           594.307002
#  488172         1406.590864
#  30328           184.879281
#  ...                    ...
#  306434           56.627057
#  42517            54.844698
#  57911           145.584897
#  216895           55.512590
#  402132          774.341848
#
#  [14356 rows x 29 columns],
#  369285    0
#  278161    1
#  31890     0
#  488172    0
#  30328     0
#           ..
#  306434    0
#  42517     0
#  57911     0
#  216895    0
#  402132    0
#  Name: y, Length: 14356, dtype: int64,
#                                    znt_ssylka  delivery_point  rasstoyanie  \
#  232442  604815f3-a024-11e6-80e9-00505601119a               1        300.0
#  564223  e996deeb-a004-11e6-80e9-00505601119a               1        800.0
#  324453  8651afc8-a039-11e6-80eb-00505601119b               1        800.0
#  329956  8898f219-a038-11e6-80eb-00505601119b               1       7300.0
#  150338  3e736c0c-a038-11e6-80eb-00505601119b               1        650.0
#  ...                                      ...             ...          ...
#  156693  410e79fa-ae1c-11ef-b865-00155d7db200               2       9175.0
#  415346  ac022b79-66e7-4b64-a830-8bc179c7f72e               2       3970.0
#  268944  6f4b70a3-b09b-11ef-9c64-3a68dd4bd927               1        600.0
#  598818  f7d439ff-c7cc-4d74-9168-4a52a37467fa               1       2000.0
#  309746  8045ee1c-b087-11ef-b865-00155d7db200               3       9430.0
#
#         date_create date_fakticheskaya_vygruzki  tonnazh  obem_znt  \
#  232442  2016-11-01                  2016-11-09    0.200     4.935
#  564223  2016-11-01                  2016-11-11    0.300     0.300
#  324453  2016-11-01                  2016-11-16    0.250     0.400
#  329956  2016-11-01                  2017-01-14    0.030     0.060
#  150338  2016-11-01                  2016-11-15    0.300     0.600
#  ...            ...                         ...      ...       ...
#  156693  2024-12-02                  2024-12-26    0.200     0.324
#  415346  2024-12-02                  2024-12-18    0.100     1.280
#  268944  2024-12-02                  2024-12-05    0.400     1.200
#  598818  2024-12-02                  2024-12-18    0.002     0.027
#  309746  2024-12-02                  2024-12-28    0.096     0.409
#
#                                             adres_zagruzki  \
#  232442  150044, Ярославская обл, г. Ярославль, ул. Ост...
#  564223  150044, Ярославская обл, г. Ярославль, ул. Ост...
#  324453  г.Иваново ул. Станкостроителей 3Б, ООО "Корона...
#  329956  Владимирская обл., Вязниковский р-он, пгт Нико...
#  150338  Владимирская обл., Вязниковский р-он, пгт Нико...
#  ...                                                   ...
#  156693  142435, Московская обл, г Ногинск, с Кудиново,...
#  415346  623753, Свердловская область, р-н Режевской, г...
#  268944  346330, Ростовская обл, г Донецк, пр-кт Ленина...
#  598818  413503, Саратовская область, р-н Ершовский, г ...
#  309746  241015, Брянская обл, Брянск г, Ульянова ул, д...
#
#                                             adres_vygruzki country_zagruzki  \
#  232442  150030, Ярославская обл, Ярославль г, Ползунов...           Россия
#  564223  394061, Воронежская обл, Воронеж г, Свердлова,...           Россия
#  324453  215113, Смоленская обл, Вяземский р-н, Вязьма ...           Россия
#  329956  676280, Амурская обл, Тында г, Привокзальная у...           Россия
#  150338  394010, Воронежская обл, Воронеж г, Богдана Хм...           Россия
#  ...                                                   ...              ...
#  156693  692830, Приморский край, Шкотовский р-н, Смоля...           Россия
#  415346  670002, Республика Бурятия, г Улан-Удэ, ул Лим...           Россия
#  268944  623428, Свердловская обл, г Каменск-Уральский,...           Россия
#  598818  165340, Архангельская область, р-н Котласский,...           Россия
#  309746  681000, Хабаровский край, г Комсомольск-на-Аму...           Россия
#
#          ... kolvo_gruzovykh_mest lt_stoimost_perevozki  \
#  232442  ...                    0                   0.0
#  564223  ...                    0                   0.0
#  324453  ...                    0                   0.0
#  329956  ...                    0                   0.0
#  150338  ...                    0                   0.0
#  ...     ...                  ...                   ...
#  156693  ...                    2               39823.0
#  415346  ...                   20               45004.0
#  268944  ...                    1               44200.0
#  598818  ...                    1               22394.0
#  309746  ...                    2               24913.0
#
#                                       voditel  year month  \
#  232442  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  564223  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  324453  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  329956  50798750-be08-11e6-80e9-00505601119a  2016    11
#  150338  f920e2f0-cfcd-11e5-80e4-005056010e02  2016    11
#  ...                                      ...   ...   ...
#  156693                                  None  2024    12
#  415346                                  None  2024    12
#  268944  1d4c99a5-a3ed-11ee-b3ef-3a68dd0e0ca7  2024    12
#  598818  c359fb80-fa43-11ed-b3eb-3a68dd0e0ca7  2024    12
#  309746                                  None  2024    12
#
#         planned_delivery_days distance_group  tonnazh_group  cost_group  \
#  232442                     8            300            0.2           0
#  564223                     9            800            0.2           0
#  324453                     9            800            0.2           0
#  329956                    30           7000            0.0           0
#  150338                     9            600            0.2           0
#  ...                      ...            ...            ...         ...
#  156693                    43           9000            0.2       30000
#  415346                    25           3000            0.1       40000
#  268944                     9            600            0.4       40000
#  598818                    14           2000            0.0       20000
#  309746                    50           9000            0.0       20000
#
#          geo_rasstoyanie_km
#  232442            7.413426
#  564223          665.840816
#  324453         6682.931393
#  329956         4871.810163
#  150338          523.634799
#  ...                    ...
#  156693         6399.175957
#  415346         2976.941083
#  268944         1731.496160
#  598818         1103.532323
#  309746         6403.867733
#
#  [241545 rows x 29 columns],
#  232442    0
#  564223    1
#  324453    1
#  329956    1
#  150338    1
#           ..
#  156693    0
#  415346    0
#  268944    0
#  598818    1
#  309746    0
#  Name: y, Length: 241545, dtype: int64)

# %%
categorical_columns = ['distance_group', 'cost_group', 'region_zagruzki', 'region_vygruzki']

features = ['delivery_point', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki',
            'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'month', 'planned_delivery_days',
            'geo_rasstoyanie_km', 'distance_group', 'tonnazh_group', 'cost_group',
            'rasstoyanie', 'tonnazh', 'lt_stoimost_perevozki']

pipe_xgboost = Pipeline(steps=[
    ('cast_category', CategoricalTypeCaster(categorical_columns=categorical_columns)),
    ('selection', FeatureSelection(features=features)),
    ('model', XGBClassifier(enable_categorical=True))
])

# %%
pipe_xgboost.fit(x_subset, y_subset)
# Out:
# [2025-05-01 21:09:18] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 21:09:19] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 21:09:19] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.31 секунд
# [2025-05-01 21:09:19] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 21:09:19] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.03 секунд
# Pipeline(steps=[('cast_category',
#                  CategoricalTypeCaster(categorical_columns=['distance_group',
#                                                             'cost_group',
#                                                             'region_zagruzki',
#                                                             'region_vygruzki'])),
#                 ('selection',
#                  FeatureSelection(features=['delivery_point', 'region_zagruzki',
#                                             'lat_zagruzki', 'lng_zagruzki',
#                                             'region_vygruzki', 'lat_vygruzki',
#                                             'lng_vygruzki', 'month',
#                                             'planned_delivery_days',
#                                             'geo_rasstoyanie_km'...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
param_grid = {
    'model__n_estimators': [100, 200],
    # 'model_boost__max_depth': [3, 5, 7],
    # 'model_boost__learning_rate': [0.01, 0.1, 0.3],
    # 'model_boost__subsample': [0.8, 1.0],
    # 'model_boost__colsample_bytree': [0.8, 1.0]
}

param_scoring = {
    'accuracy': make_scorer(accuracy_score),
    'f1': make_scorer(f1_score),
    'ap': make_scorer(average_precision_score)
}

tss = TimeSeriesSplit(n_splits=3)

search = GridSearchCV(estimator=pipe_xgboost,
                      param_grid=param_grid,
                      scoring=param_scoring,
                      refit='ap',
                      cv=tss,
                      n_jobs=-1,
                      verbose=10,
                      return_train_score=True
                      )
search.fit(x_subset, y_subset)

print(f"Лучшие параметры модели: {search.best_params_}")
best_model = search.best_estimator_
# Out:
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# [2025-05-01 21:41:49] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 21:41:49] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 21:41:49] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.22 секунд
# [2025-05-01 21:41:49] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 21:41:49] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.04 секунд
# Лучшие параметры модели: {'model__n_estimators': 100}

# %%
thresholds = np.linspace(0.1, 0.9, 81)

best_thresholds = []
best_auc_scores = []
best_f1 = []
best_precision = []
best_recall = []

for train_idx, val_idx in tss.split(x_train):
    X_train_thresh, X_val_thresh = x_train.iloc[train_idx], x_train.iloc[val_idx]
    y_train_thresh, y_val_thresh = y_train.iloc[train_idx], y_train.iloc[val_idx]
    
    best_model.fit(X_train_thresh, y_train_thresh)
    val_probs = best_model.predict_proba(X_val_thresh)[:, 1]

    precision_scores = []
    recall_scores = []
    f1_scores = []

    for thresh in thresholds:
        val_pred = (val_probs >= thresh).astype(int)
        precision_train, recall_train, f1_train, _ = precision_recall_fscore_support(
            y_val_thresh, val_pred, average='binary'
        )
        precision_scores.append(precision_train)
        recall_scores.append(recall_train)
        f1_scores.append(f1_train)

    best_idx = np.argmax(f1_scores)
    best_thresholds.append(thresholds[best_idx])
    best_precision.append(precision_scores[best_idx])
    best_recall.append(recall_scores[best_idx])
    best_f1.append(f1_scores[best_idx])

    best_auc_scores.append(average_precision_score(y_val_thresh, val_probs))

optimal_threshold = np.mean(best_thresholds)
optimal_precision = np.mean(best_precision)
optimal_recall = np.mean(best_recall)
optimal_f1 = np.mean(best_f1)
optimal_auc = np.mean(best_auc_scores)


y_test_proba = best_model.predict_proba(x_test)[:, 1]

y_best_test_pred = (y_test_proba >= optimal_threshold).astype(int)
precision_test, recall_test, f1_test, _ = precision_recall_fscore_support(
    y_test, y_best_test_pred, average='binary'
)
auc_fr_test = average_precision_score(y_test, y_test_proba)

results = {
    'threshold': optimal_threshold,
    'train': {
        'precision': round(optimal_precision, 4),
        'recall': round(optimal_recall, 4),
        'f1': round(optimal_f1, 4),
        'ap': round(optimal_auc, 4)
    },
    'test': {
        'precision': round(precision_test, 4),
        'recall': round(recall_test, 4),
        'f1': round(f1_test, 4),
        'ap': round(auc_fr_test, 4)
    }
}

df_result = pd.DataFrame(results).T
df_result
# Out:
# [2025-05-01 22:30:23] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:23] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:23] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.14 секунд
# [2025-05-01 22:30:23] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:23] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.03 секунд
# [2025-05-01 22:30:24] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:24] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:24] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.16 секунд
# [2025-05-01 22:30:24] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:24] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.03 секунд
# [2025-05-01 22:30:25] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:26] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:26] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.27 секунд
# [2025-05-01 22:30:26] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:26] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.04 секунд
# [2025-05-01 22:30:27] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:27] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:27] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.18 секунд
# [2025-05-01 22:30:27] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:27] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.02 секунд
# [2025-05-01 22:30:29] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:29] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:29] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.37 секунд
# [2025-05-01 22:30:29] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:29] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.05 секунд
# [2025-05-01 22:30:31] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:31] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:31] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.16 секунд
# [2025-05-01 22:30:31] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:31] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.03 секунд
# [2025-05-01 22:30:33] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoricalTypeCaster.transform'
# [2025-05-01 22:30:33] [ERROR] [column_transformers.CategoricalTypeCaster.transform] Не найдены категориальные фичи: []
# [2025-05-01 22:30:33] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoricalTypeCaster.transform'. Время выполнения: 0.09 секунд
# [2025-05-01 22:30:33] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureSelection.transform'
# [2025-05-01 22:30:33] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureSelection.transform'. Время выполнения: 0.01 секунд
#            precision    recall        f1        ap
# threshold   0.196667  0.196667  0.196667  0.196667
# train       0.404800  0.828400  0.542800  0.449400
# test        0.258900  0.897700  0.401900  0.419400

# %% [markdown]
# ## Работа с параметрами и поиск возможности улучшений

# %%
from src.utils import decorators, logger
from src.data_loader import raw_data_loader
from src.preprocessor import preprocessing
from src.splitter import splitter
from src.pipeline import data_preparation_pipeline, model_pipeline
from src.model_selection import evaluate, search, threshold
from src.features import column_transformers

importlib.reload(decorators)
importlib.reload(logger)
importlib.reload(raw_data_loader)
importlib.reload(splitter)
importlib.reload(preprocessing)
importlib.reload(data_preparation_pipeline)
importlib.reload(model_pipeline)
importlib.reload(evaluate)
importlib.reload(search)
importlib.reload(threshold)
importlib.reload(column_transformers)

from src.utils.decorators import start_finish_function
from src.utils.logger import CustomFormatter
from src.data_loader.raw_data_loader import get_df
from src.preprocessor.preprocessing import ManagerPreprocessing
from src.splitter.splitter import FixedDateTrainTestSplitter, TimeBasedSubsetSelector, SplitManager
from src.pipeline.data_preparation_pipeline import TrainTestPreparer
from src.pipeline.model_pipeline import XGBoostPipelineBuilder, LogistRegPipeline
from src.model_selection.evaluate import evaluate_on_test
from src.model_selection.search import search_best_model
from src.model_selection.threshold import ThresholdOptimizer

from src.features.column_transformers import FeatureSelection, CategoricalTypeCaster

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
# Надо получить готовые данные закодировать фичи к правильный формат и проверить качесво
engine = dbm.get_engine()

df = get_df(engine)
feature_name = ['delivery_point', 'rasstoyanie', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'date_create', 'tonnazh', 'obem_znt', 'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki']

# Разделение на тест, трейн и подбора гипер параметров
x_train, y_train, x_test, y_test, x_subset, y_subset = TrainTestPreparer(feature_columns=feature_name).prepare(df)
# Out:
# [2025-05-08 17:41:06] [INFO] [decorators.wrapper] Старт выполнения метода 'Engine.get_df'
# [2025-05-08 17:41:19] [INFO] [decorators.wrapper] Завершение выполнения метода 'Engine.get_df'. Время выполнения: 13.16 секунд
# [2025-05-08 17:41:19] [INFO] [decorators.wrapper] Старт выполнения метода 'TrainTestPreparer.prepare'
# [2025-05-08 17:41:20] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing.preprocess'
# [2025-05-08 17:41:20] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing._dropna'
# [2025-05-08 17:41:20] [INFO] [preprocessing.ManagerPreprocessing._dropna] Удалено пустых столбцов: 295 шт, осталось 618328
# [2025-05-08 17:41:20] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing._dropna'. Время выполнения: 0.51 секунд
# [2025-05-08 17:41:20] [INFO] [decorators.wrapper] Старт выполнения метода 'DatetimePreprocessor.transform'
# [2025-05-08 17:41:21] [INFO] [decorators.wrapper] Завершение выполнения метода 'DatetimePreprocessor.transform'. Время выполнения: 0.68 секунд
# [2025-05-08 17:41:21] [INFO] [decorators.wrapper] Старт выполнения метода 'TargetCreator.transform'
# [2025-05-08 17:41:33] [INFO] [decorators.wrapper] Завершение выполнения метода 'TargetCreator.transform'. Время выполнения: 12.06 секунд
# [2025-05-08 17:41:33] [INFO] [decorators.wrapper] Старт выполнения метода 'RareCityDropper.transform'
# [2025-05-08 17:41:34] [INFO] [decorators.wrapper] Завершение выполнения метода 'RareCityDropper.transform'. Время выполнения: 1.39 секунд
# [2025-05-08 17:41:35] [INFO] [decorators.wrapper] Старт выполнения метода 'CategoryFeatureEngineer.transform'
# [2025-05-08 17:41:36] [INFO] [decorators.wrapper] Завершение выполнения метода 'CategoryFeatureEngineer.transform'. Время выполнения: 1.26 секунд
# [2025-05-08 17:41:36] [INFO] [decorators.wrapper] Старт выполнения метода 'GeospatialFeatureEngineer.transform'
# [2025-05-08 17:41:36] [INFO] [decorators.wrapper] Завершение выполнения метода 'GeospatialFeatureEngineer.transform'. Время выполнения: 0.23 секунд
# [2025-05-08 17:41:36] [INFO] [decorators.wrapper] Старт выполнения метода 'ManagerPreprocessing.set_correct_datetype'
# [2025-05-08 17:41:37] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing.set_correct_datetype'. Время выполнения: 0.85 секунд
# [2025-05-08 17:41:37] [INFO] [decorators.wrapper] Завершение выполнения метода 'ManagerPreprocessing.preprocess'. Время выполнения: 17.10 секунд
# [2025-05-08 17:41:38] [INFO] [decorators.wrapper] Старт выполнения метода 'SplitManager.run'
# [2025-05-08 17:41:38] [INFO] [decorators.wrapper] Старт выполнения метода 'FixedDateTrainTestSplitter.split'
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Завершение выполнения метода 'FixedDateTrainTestSplitter.split'. Время выполнения: 0.94 секунд
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.18 секунд
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.01 секунд
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Завершение выполнения метода 'SplitManager.run'. Время выполнения: 1.16 секунд
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Старт выполнения метода 'SplitManager.run'
# [2025-05-08 17:41:39] [INFO] [decorators.wrapper] Старт выполнения метода 'FixedDateTrainTestSplitter.split'
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Завершение выполнения метода 'FixedDateTrainTestSplitter.split'. Время выполнения: 0.82 секунд
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Старт выполнения метода 'TimeBasedSubsetSelector.select'
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Завершение выполнения метода 'TimeBasedSubsetSelector.select'. Время выполнения: 0.78 секунд
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.06 секунд
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Старт выполнения метода 'FeatureTargetSplitter.split'
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Завершение выполнения метода 'FeatureTargetSplitter.split'. Время выполнения: 0.02 секунд
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Завершение выполнения метода 'SplitManager.run'. Время выполнения: 1.74 секунд
# [2025-05-08 17:41:40] [INFO] [decorators.wrapper] Завершение выполнения метода 'TrainTestPreparer.prepare'. Время выполнения: 21.51 секунд

# %%
x_train.columns
# Out:
# Index(['znt_ssylka', 'delivery_point', 'rasstoyanie', 'date_create',
#        'date_fakticheskaya_vygruzki', 'tonnazh', 'obem_znt', 'adres_zagruzki',
#        'adres_vygruzki', 'country_zagruzki', 'region_zagruzki',
#        'city_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'country_vygruzki',
#        'region_vygruzki', 'city_vygruzki', 'lat_vygruzki', 'lng_vygruzki',
#        'kolvo_gruzovykh_mest', 'lt_stoimost_perevozki', 'voditel', 'year',
#        'month', 'planned_delivery_days', 'distance_group', 'tonnazh_group',
#        'cost_group', 'geo_rasstoyanie_km'],
#       dtype='object')

# %%
categorical_columns = ['distance_group', 'cost_group', 'region_zagruzki', 'region_vygruzki']

features = ['delivery_point', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki',
            'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'month', 'planned_delivery_days',
            'geo_rasstoyanie_km', 'distance_group', 'tonnazh_group', 'cost_group',
            'rasstoyanie', 'tonnazh', 'lt_stoimost_perevozki']

param_scoring = {
    'accuracy': make_scorer(accuracy_score),
    'f1': make_scorer(f1_score),
    'ap': make_scorer(average_precision_score)
}

tss = TimeSeriesSplit(n_splits=3)

pipe_xgboost = XGBoostPipelineBuilder(features, categorical_columns).build()

search = search_best_model(pipe_xgboost, param_grid, param_scoring, x_subset, y_subset, refit_metric='ap')
best_model = search.best_estimator_

optimizer = ThresholdOptimizer(best_model)
optimal_threshold, train_metrics = optimizer.optimize(x_train, y_train, tss)

# Финальная проверка на тесте
test_metrics = evaluate_on_test(best_model, x_test, y_test, optimal_threshold)

JsonAppendLogger(
    "artifacts/params.json", key_name="params", prefix="xgb"
).append(best_model.named_steps['model'].get_params())
JsonAppendLogger(
    "artifacts/metrics.json", key_name="metrics", prefix="xgb"
).append(results)

# %%
features = ['delivery_point', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki',
            'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'month', 'planned_delivery_days',
            'geo_rasstoyanie_km', 'distance_group', 'tonnazh_group', 'cost_group',
            'rasstoyanie', 'tonnazh', 'lt_stoimost_perevozki']

categorical_columns = ['distance_group', 'cost_group', 'region_zagruzki', 'region_vygruzki']
other_features = ['month']

numeric_features = list(set(x_train[features].select_dtypes(exclude=object).columns) - set(categorical_columns) - set(other_features))

# %%
x_subset[numeric_features]
# Out:
#         lng_zagruzki  geo_rasstoyanie_km  rasstoyanie  delivery_point  \
# 232442     39.815579            7.413426        300.0               1
# 564223     39.815579          665.840816        800.0               1
# 324453    132.571133         6682.931393        800.0               1
# 329956     41.993895         4871.810163       7300.0               1
# 150338     41.993895          523.634799        650.0               1
# ...              ...                 ...          ...             ...
# 156693     38.230520         6399.175957       9175.0               2
# 415346     61.417735         2976.941083       3970.0               2
# 268944     39.945619         1731.496160        600.0               1
# 598818     48.278302         1103.532323       2000.0               1
# 309746     34.316785         6403.867733       9430.0               3
#
#         tonnazh  lat_zagruzki  planned_delivery_days  tonnazh_group  \
# 232442    0.200     57.659344                      8            0.2
# 564223    0.300     57.659344                      9            0.2
# 324453    0.250     42.845616                      9            0.2
# 329956    0.030     56.140479                     30            0.0
# 150338    0.300     56.140479                      9            0.2
# ...         ...           ...                    ...            ...
# 156693    0.200     55.761371                     43            0.2
# 415346    0.100     57.375378                     25            0.1
# 268944    0.400     48.319376                      9            0.4
# 598818    0.002     51.345328                     14            0.0
# 309746    0.096     53.308483                     50            0.0
#
#         lng_vygruzki  lat_vygruzki  lt_stoimost_perevozki
# 232442     39.880042     57.602301                    0.0
# 564223     39.205102     51.681643                    0.0
# 324453     34.346061     55.191870                    0.0
# 329956    124.740105     55.139967                    0.0
# 150338     39.275602     51.710694                    0.0
# ...              ...           ...                    ...
# 156693    132.453310     43.278198                39823.0
# 415346    107.614668     51.840980                45004.0
# 268944     61.917234     56.427617                44200.0
# 598818     46.903368     61.240826                22394.0
# 309746    136.987152     50.554313                24913.0
#
# [241545 rows x 11 columns]

# %%
lgr = LogistRegPipeline(features=features, categorical_columns=categorical_columns, numeric_features=numeric_features, other_features=other_features).build()
# Out:
# [2025-05-08 01:01:09] [DEBUG] [model_pipeline.LogistRegPipeline.__init__] Используемые колонки: ['delivery_point', 'region_zagruzki', 'lat_zagruzki', 'lng_zagruzki', 'region_vygruzki', 'lat_vygruzki', 'lng_vygruzki', 'month', 'planned_delivery_days', 'geo_rasstoyanie_km', 'distance_group', 'tonnazh_group', 'cost_group', 'rasstoyanie', 'tonnazh', 'lt_stoimost_perevozki']

# %%
x_subset.dtypes
# Out:
# znt_ssylka                             object
# delivery_point                          int64
# rasstoyanie                           float64
# date_create                    datetime64[ns]
# date_fakticheskaya_vygruzki    datetime64[ns]
# tonnazh                               float64
# obem_znt                              float64
# adres_zagruzki                         object
# adres_vygruzki                         object
# country_zagruzki                       object
# region_zagruzki                        object
# city_zagruzki                          object
# lat_zagruzki                          float64
# lng_zagruzki                          float64
# country_vygruzki                       object
# region_vygruzki                        object
# city_vygruzki                          object
# lat_vygruzki                          float64
# lng_vygruzki                          float64
# kolvo_gruzovykh_mest                    int64
# lt_stoimost_perevozki                 float64
# voditel                                object
# year                                    int32
# month                                   int32
# planned_delivery_days                   int64
# distance_group                          int64
# tonnazh_group                         float64
# cost_group                              int64
# geo_rasstoyanie_km                    float64
# dtype: object

# %%
lgr.fit(x_subset, y_subset)
# Out:
# C:\Users\Stepan\ds\prediction_success_delivery\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('transform',
#                  ColumnTransformer(transformers=[('numerical', StandardScaler(),
#                                                   ['lng_zagruzki',
#                                                    'geo_rasstoyanie_km',
#                                                    'rasstoyanie',
#                                                    'delivery_point', 'tonnazh',
#                                                    'lat_zagruzki',
#                                                    'planned_delivery_days',
#                                                    'tonnazh_group',
#                                                    'lng_vygruzki',
#                                                    'lat_vygruzki',
#                                                    'lt_stoimost_perevozki']),
#                                                  ('categorical',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['distance_group',
#                                                    'cost_group',
#                                                    'region_zagruzki',
#                                                    'region_vygruzki']),
#                                                  ('other', 'passthrough',
#                                                   ['month'])])),
#                 ('model', LogisticRegression(penalty=None))])

# %%
lgr.predict_proba(x_test)
# Out:
# array([[0.66210797, 0.33789203],
#        [0.54681411, 0.45318589],
#        [0.6644918 , 0.3355082 ],
#        ...,
#        [0.81441775, 0.18558225],
#        [0.96182883, 0.03817117],
#        [0.77981927, 0.22018073]])
